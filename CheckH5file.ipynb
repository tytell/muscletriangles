# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
filename = './rawdata/20180629_L131/MUSCLE A/001-stim-15-unpert-pass.h5'

# %%
with h5py.File(filename,'r') as f:
    force = np.array(f['/RawInput/Force'])
    length = np.array(f['/RawInput/Length'])

# %%
length
# Out:
# array([6.62      , 6.62032862, 6.62016431, ..., 6.62082155, 6.62      ,
#        6.62049293])

# %%
plt.plot(length)

# %%
plt.plot(force)
